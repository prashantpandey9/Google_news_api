# %% [markdown]
# # Modules added

# %%
import requests
import json
from bs4 import BeautifulSoup
from datetime import datetime
now = datetime.now()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2c2acc67f8cd> in <module>
#       1 import requests
#       2 import json
# ----> 3 from bs4 import BeautifulSoup
#       4 from datetime import datetime
#       5 now = datetime.now()
#
# ModuleNotFoundError: No module named 'bs4'

# %%
url="https://news.google.com/topics/CAAqBwgKMMqAmAsw9KmvAw?hl=en-IN&gl=IN&ceid=IN%3Aen" #google news URL for scraping it.
q=requests.get(url)
soup=BeautifulSoup(q.text,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <base href="https://news.google.com/"/>
#   <meta content="origin" name="referrer"/>
#   <link href="https://news.google.com/topics/CAAqBwgKMMqAmAsw9KmvAw" rel="canonical"/>
#   <meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/>
#   <meta content="AcBy5YFny2HQgVUCR18tO5YUTf6MpVlcJqGTd-a9-SI" name="google-site-verification"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="News" name="application-name"/>
#   <meta content="News" name="apple-mobile-web-app-title"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="white" name="theme-color"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w16" rel="shortcut icon" sizes="16x16"/>
#   <link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w24" rel="shortcut icon" sizes="24x24"/>
#   <link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w32" rel="shortcut icon" sizes="32x32"/>
#   <link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w48" rel="shortcut icon" sizes="48x48"/>
#   <link href="//www.gstatic.com" rel="preconnect"/>
#   <link href="//fonts.gstatic.com" rel="preconnect"/>
#   <link href="//lh3.googleusercontent.com" rel="preconnect"/>
#   <link href="//lh4.googleusercontent.com" rel="preconnect"/>
#   <link href="//lh5.googleusercontent.com" rel="preconnect"/>
#   <link href="//lh6.googleusercontent.com" rel="preconnect"/>
#   <link href="//ssl.gstatic.com" rel="preconnect"/>
#   <link href="//maps.googleapis.com" rel="preconnect"/>
#   <link href="https://www.google-analytics.com/analytics.js" rel="preconnect"/>
#   <link crossorigin="use-credentials" href="_/DotsSplashUi/manifest.json" rel="manifest"/>
#   <link href="/?lfhs=2" rel="home"/>
#   <link href="/?lfhs=2" rel="msapplication-starturl"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="icon" sizes="192x192"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="apple-touch-icon-precomposed" sizes="192x192"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="msapplication-square192x192logo" sizes="192x192"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="icon" sizes="512x512"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="apple-touch-icon-precomposed" sizes="512x512"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="msapplication-square512x512logo" sizes="512x512"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="icon" sizes="1024x1024"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="apple-touch-icon-precomposed" sizes="1024x1024"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="msapplication-square1024x1024logo" sizes="1024x1024"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="icon" sizes="120x120"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="msapplication-square120x120logo" sizes="120x120"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="icon" sizes="152x152"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="msapplication-square152x152logo" sizes="152x152"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="icon" sizes="167x167"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="apple-touch-icon-precomposed" sizes="167x167"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="msapplication-square167x167logo" sizes="167x167"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_180.png" rel="icon" sizes="180x180"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_180.png" rel="msapplication-square180x180logo" sizes="180x180"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_80.png" rel="icon" sizes="80x80"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_80.png" rel="apple-touch-icon-precomposed" sizes="80x80"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_80.png" rel="msapplication-square80x80logo" sizes="80x80"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_87.png" rel="icon" sizes="87x87"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_87.png" rel="apple-touch-icon-precomposed" sizes="87x87"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_87.png" rel="msapplication-square87x87logo" sizes="87x87"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_58.png" rel="icon" sizes="58x58"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_58.png" rel="apple-touch-icon-precomposed" sizes="58x58"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_58.png" rel="msapplication-square58x58logo" sizes="58x58"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_60.png" rel="icon" sizes="60x60"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_60.png" rel="apple-touch-icon-precomposed" sizes="60x60"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_60.png" rel="msapplication-square60x60logo" sizes="60x60"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_40.png" rel="icon" sizes="40x40"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_40.png" rel="apple-touch-icon-precomposed" sizes="40x40"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_40.png" rel="msapplication-square40x40logo" sizes="40x40"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="apple-touch-startup-image" sizes="192x192"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="apple-touch-startup-image" sizes="512x512"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="apple-touch-startup-image" sizes="1024x1024"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="apple-touch-startup-image" sizes="120x120"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="apple-touch-startup-image" sizes="152x152"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="apple-touch-startup-image" sizes="167x167"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_180.png" rel="apple-touch-startup-image" sizes="180x180"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_80.png" rel="apple-touch-startup-image" sizes="80x80"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_87.png" rel="apple-touch-startup-image" sizes="87x87"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_58.png" rel="apple-touch-startup-image" sizes="58x58"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_60.png" rel="apple-touch-startup-image" sizes="60x60"/>
#   <link href="//ssl.gstatic.com/gnews/logo/google_news_40.png" rel="apple-touch-startup-image" sizes="40x40"/>
#   <script data-id="_gd" nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    window.WIZ_global_data = {"DpimGf":false,"EP1ykd":["/_/*","/accounts/*","/subscribewithgoogleclientui/*","/swg/*","/swglib/*"],"FdrFJe":"8274860772372388590","Fwhl2e":"%.@.[\"en-IN\",\"IN\",[\"SPORTS_FULL_COVERAGE\",\"WEB_TEST_1_0_0\"]\n,null,null,1,1,\"IN:en\",null,null,null,\"CAISCwixnoD2BRCA9455\"]\n,\"en-IN\",\"IN\",true,[3,14,1]\n,1,true,\"311548027\",false,false]\n","GASP4":1333,"Im6cmf":"/_/DotsSplashUi","LVIXXb":1,"LoQv7e":false,"MT7f9b":[],
uyeh42a2nnqj7cjrccz4","VK2PK":"true","OOSz1d":"xh6c7vle6ed77uc3mx3bawjnoq","UDNf6e":"true","nFxYJe":"nfw7bs6rw5ltjadd3qkury3gwe","sZrVKc":"true","DCFoTd":"false","lGu6U":"false","wcLcde":"false","tBSlob":"false"},"qwAQke":"DotsSplashUi","qymVe":"thsaqCt5k2payz2AhFbZG0G0p0o","rtQCxc":-330,"utHyne":{"/_/notifications/sw.js?xhrRoot\u003d/_/DotsSplashUi\u0026mssRowKey\u003dboq-dots.DotsSplashUi.en_IN.luc2kNNg3G0.es5.O\u0026buildLabel\u003dboq_dotssplashserver_20200508.12_p6\u0026initialJsPath\u003dhttps://www.gstatic.com/_/mss/boq-dots/_/js/k%3Dboq-dots.DotsSplashUi.en_IN.luc2kNNg3G0.es5.O/am%3DCrEtAAQg/d%3D1/excm%3D_b,_tp,collection/ed%3D1/dg%3D0/wt%3D2/ct%3Dzgms/rs%3DALs0n2NPUQLYLAGRJ2CNBAhWhovcDNuV9g/m%3D_b,_tp":"knQkrc","/dss ...
#   </script>
#   <script nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    (function(){/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# 'use strict';var a=window,c=a.performance,l=k();a.cc_latency_start_time=c&&c.now?0:c&&c.timing&&c.timing.navigationStart?c.timing.navigationStart:l;function k(){return c&&c.now?c.now():(new Date).getTime()}function n(f){if(c&&c.now&&c.mark){var g=c.mark(f);if(g)return g.startTime;if(c.getEntriesByName&&(f=c.getEntriesByName(f).pop()))return f.startTime}return k()}a.onaft=function(){n("aft")};
# a.l=function(f){function g(b){var e={};e[b]=k();a.cc_latency.push(e)}function m(b){var e=n("iml");b.setAttribute("data-iml",e)}a.cc_aid=f;a.iml_start=a.cc_latency_start_time;a.css_size=0;a.cc_latency=[];a.ccTick=g;a.onJsLoad=function(){g("jsl")};a.onCssLoad=function(){g("cssl")};a._isVisible=function(b,e,h){if(!e||"none"==e.style.display)return!1;var d=b.defaultView;if(d&&d.getComputedStyle&&(d=d.getComputedStyle(e),"hidden"==d.visibility||"0px"==d.height||"0px"==d.width))return!1;if(!e.getBoundingClientRect)return!0;
# d=h?h:e.getBoundingClientRect();e=d.left+a.pageXOffset;h=d.top+a.pageYOffset;if(0>h+d.height||0>e+d.width||0>=d.height||0>=d.width)return!1;b=b.documentElement;return h<=(a.innerHeight||b.clientHeight)&&e<=(a.innerWidth||b.clientWidth)};a._recordImlEl=m;document.documentElement.addEventListener("load",function(b){b=b.target;"IMG"!=b.tagName||b.hasAttribute("data-iid")||b.hasAttribute("data-src")||b.hasAttribute("data-ils")||b.hasAttribute("data-noaft")||m(b);if(a.aft_counter&&(b=a.aft_counter.indexOf(b),
# -1!==b&&(b=1===a.aft_counter.splice(b,1).length,0===a.aft_counter.length&&b)))a.onaft(k())},!0);a.prt=-1;a.wiz_tick=function(){var b=n("prt");a.prt=b}};}).call(this);
# l('AAbh7b')
#   </script>
#   <script nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    var _F_cssRowKey = 'boq-dots.DotsSplashUi.Lih55RO325A.L.W.O';var _F_combinedSignature = 'ALs0n2NjpaD3KQpYFHw0ttXK4aBawMseIA';function _DumpException(e) {throw e;}
#   </script>
#   <style data-href="https://www.gstatic.com/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi.Lih55RO325A.L.W.O/am=CrEtAAQg/d=1/ed=1/ct=zgms/rs=ALs0n2Pl4vJ30TQFN361kxVBubRp-RqtLQ/m=collection,_b,_tp" nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    html{height:100%;overflow:hidden}body{height:100%;overflow:hidden;-webkit-font-smoothing:antialiased;color:rgba(0,0,0,0.87);font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif;margin:0;-webkit-text-size-adjust:100%;-webkit-text-size-adjust:100%;text-size-adjust:100%}textarea{font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif}a{text-decoration:none;color:#2962ff}img{border:none}*{-webkit-tap-highlight-color:transparent}#apps-debug-tracers{display:none}html{overflow:visible}body{overflow:visible;overflow-y:scroll}@keyframes mdc-ripple-fg-radius-in{0%{-webkit-animation-timing-function:cubic-bezier(0.4,0,0.2,1);animation-timing-function:cubic-bezier(0.4,0,0.2,1);-webkit-transform:translate(var(--mdc-ripple-fg-translate-start,0)) scale(1);transform:translate(var(--mdc-ripple-fg-translate-start,0)) scale(1)}to{-webkit-transform:translate(var(--mdc-ripple-fg-translate-end,0)) scale(var(--mdc-ripple-fg-scale,1));transform:translate(var(--mdc-ripple-fg-translate-end,0)) scale(var(--mdc-ripple-fg-scale,1))}}@keyframes mdc-ripple-fg-opacity-in{0%{-webkit-animation-timing-function:linear;animation-timing-function:linear;opacity:0}to{opacity:var(--mdc-ripple-fg-opacity,0)}}@keyframes mdc-ripple-fg-opacity-out{0%{-webkit-animation-timing-function:linear;animation-timing-function:linear;opacity:var(--mdc-ripple-fg-opacity,0)}to{opacity:0}}.VfPpkd-ksKsZd-XxIAqe{--mdc-ripple-fg-size:0;--mdc-ripple-left:0;--mdc-ripple-top:0;--mdc-ripple-fg-scale:1;--mdc-ripple-fg-translate-end:0;--mdc-ripple-fg-translate-start:0;-webkit-tap-highlight-color:rgba(0,0,0,0);will-change:transform,opacity;position:relative;outline:none;overflow:hidden}.VfPpkd-ksKsZd-XxIAqe::before{position:absolute;-webkit-border-radius:50%;border-radius:50%;opacity:0;pointer-events:none;content:""}.VfPpkd-ksKsZd-XxIAqe::after{position:absolute;-webkit-border-radius:50%;border-radius:50%;opacity:0;pointer-events:none;content:""}.VfPpkd-ksKsZd-XxIAqe::before{-webkit-transition:opacity 15ms linear,background-color 15ms linear;transition:opacity 15ms linear,background-color 15ms linear;z-index:1}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d::before{-webkit-transform:scale(var(--mdc-ripple-fg-scale,1));transform:scale(var(--mdc-ripple-fg-scale,1))}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d::after{top:0;left:0;-webkit-transform:scale(0);transform:scale(0);-webkit-transform-origin:center center;transform-origin:center center}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d-OWXEXe-ZNMTqd::after{top:var(--mdc-ripple-top,0);left:var(--mdc-ripple-left,0)}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d-OWXEXe-Tv8l5d-lJfZMc::after{-webkit-animation:mdc-ripple-fg-radius-in 225ms forwards,mdc-ripple-fg-opacity-in 75ms forwards;animation:mdc-ripple-fg-radius-in 225ms forwards,mdc-ripple-fg-opacity-in 75ms forwards}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d-OWXEXe-Tv8l5d-OmS1vf::after{-webkit-animation:mdc-ripple-fg-opacity-out 150ms;animation:mdc-ripple-fg-opacity-out 150ms;-webkit-transform:translate(var(--mdc-ripple-fg-translate-end,0)) scale(var(--mdc-ripple-fg-scale,1));transform:translate(var(--mdc-ripple-fg-translate-end,0)) scale(var(--mdc-ripple-fg-scale,1))}.VfPpkd-ksKsZd-XxIAqe::before{background-color:#000}.VfPpkd-ksKsZd-XxIAqe::after{background-color:#000}.VfPpkd-ksKsZd-XxIAqe:hover::before{opacity:.04}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d-OWXEXe-AHe6Kc-XpnDCe::before{-webkit-transition-duration:75ms;transition-duration:75ms;opacity:.12}.VfPpkd-ksKsZd-XxIAqe:not(.VfPpkd-ksKsZd-mWPk3d):focus::before{-webkit-transition-duration:75ms;transition-duration:75ms;opacity:.12}.VfPpkd-ksKsZd-XxIAqe:not(.VfPpkd-ksKsZd-mWPk3d)::after{-webkit-transition:opacity 150ms linear;transition:opacity 150ms linear}.VfPpkd-ksKsZd-XxIAqe:not(.VfPpkd-ksKsZd-mWPk3d):active::after{-webkit-transition-duration:75ms;transition-duration:75ms;opacity:.12}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d{--mdc-ripple-fg-opacity:.12}.VfPpkd-ksKsZd-XxIAqe::before{top:-webkit-calc(50% - 100%);top:calc(50% - 100%);left:-we ...
# /*# sourceURL=/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi.Lih55RO325A.L.W.O/am=CrEtAAQg/d=1/ed=1/ct=zgms/rs=ALs0n2Pl4vJ30TQFN361kxVBubRp-RqtLQ/m=collection,_b,_tp */
#   </style>
#   <script nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    onCssLoad();
#   </script>
#   <style nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    @font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:local('Roboto Bold'),local('Roboto-Bold'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}@font-face{font-family:'Material Icons Extended';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/materialiconsextended/v50/kJEjBvgX7BgnkSrUwT8UnLVc38YydejYY-oE_LvM.ttf)format('truetype');}.material-icons-extended{font-family:'Material Icons Extended';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;}@font-face{font-family:'Product Sans';font-style:normal;font-weight:400;src:local('Product Sans'),local('ProductSans-Regular'),url(//fonts.gstatic.com/s/productsans/v9/pxiDypQkot1TnFhsFMOfGShVF9eL.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:400;src:local('Google Sans Regular'),local('GoogleSans-Regular'),url(//fonts.gstatic.com/s/googlesans/v14/4UaGrENHsxJlGDuGo1OIlL3Owps.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:500;src:local('Google Sans Medium'),local('GoogleSans-Medium'),url(//fonts.gstatic.com/s/googlesans/v14/4UabrENHsxJlGDuGo1OIlLU94YtzCwM.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:700;src:local('Google Sans Bold'),local('GoogleSans-Bold'),url(//fonts.gstatic.com/s/googlesans/v14/4UabrENHsxJlGDuGo1OIlLV154tzCwM.ttf)format('truetype');}
#   </style>
#   <script nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    (function(){/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# 'use strict';var e=this||self;
# function aa(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var d=Object.prototype.toString.call(a);if("[object Window]"==d)return"object";if("[object Array]"==d||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";if("[object Function]"==d||"undefined"!=typeof a.call&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";else if("function"==
# b&&"undefined"==typeof a.call)return"object";return b}var f=Date.now||function(){return+new Date};/*
#
#  Copyright 2011 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2013 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# var u={};function ba(a,b){if(null===b)return!1;if("contains"in a&&1==b.nodeType)return a.contains(b);if("compareDocumentPosition"in a)return a==b||!!(a.compareDocumentPosition(b)&16);for(;b&&a!=b;)b=b.parentNode;return b==a};function ca(a,b){return function(d){d||(d=window.event);return b.call(a,d)}}function x(a){a=a.target||a.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);return a}var da="undefined"!=typeof navigator&&/Macintosh/.test(navigator.userAgent),ea="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),fa={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1};
# function ha(a){return(a=a.changedTouches&&a.changedTouches[0]||a.touches&&a.touches[0])?{clientX:a.clientX,clientY:a.clientY,screenX:a.screenX,screenY:a.screenY}:null}
# function ia(a){var b={};b.originalEventType=a.type;b.type="click";for(var d in a){var c=a[d];"type"==d||"srcElement"==d||"function"==aa(c)||(b[d]=c)}b.timeStamp=f();b.defaultPrevented=!1;b.preventDefault=ja;b._propagationStopped=!1;b.stopPropagation=ma;if(a=ha(a))b.clientX=a.clientX,b.clientY=a.clientY,b.screenX=a.screenX,b.screenY=a.screenY;return b}function na(){this._mouseEventsPrevented=!0}function ja(){this.defaultPrevented=!0}function ma(){this._propagationStopped=!0}
# var oa={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},pa={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},qa={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0},ra={A:!0,AREA:!0,BUTTON:!0,DIALOG:!0,IMG:!0,INPUT:!0,LINK:!0,
# MENU:!0,OPTGROUP:!0,OPTION:!0,PROGRESS:!0,SELECT:!0,TEXTAREA:!0};/*
#
#  Copyright 2020 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2005 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# function sa(){this.j=[];this.a=[];this.c=[];this.i={};this.b=null;this.g=[]}var z,ta,ua="undefined"!=typeof navigator&&/iPhone|iPad|iPod/.test(navigator.userAgent),va=String.prototype.trim?function(a){return a.trim()}:function(a){return a.replace(/^\s+/,"").replace(/\s+$/,"")},wa=/\s*;\s*/,A=null;
# function xa(a,b){return function v(c,h){h=void 0===h?!0:h;var n=b;if("click"==n&&(da&&c.metaKey||!da&&c.ctrlKey||2==c.which||null==c.which&&4==c.button||c.shiftKey))n="clickmod";else{var l=c.which||c.keyCode;ea&&3==l&&(l=13);if(13!=l&&32!=l)l=!1;else{var g=x(c),m;(m="keydown"!=c.type||!!(!("getAttribute"in g)||(g.getAttribute("type")||g.tagName).toUpperCase()in qa||"BUTTON"==g.tagName.toUpperCase()||g.type&&"FILE"==g.type.toUpperCase()||g.isContentEditable)||c.ctrlKey||c.shiftKey||c.altKey||c.metaKey||
# (g.getAttribute("type")||g.tagName).toUpperCase()in pa&&32==l)||((m=g.tagName in fa)||(m=g.getAttributeNode("tabindex"),m=null!=m&&m.specified),m=!(m&&!g.disabled));if(m)l=!1;else{m=(g.getAttribute("role")||g.type||g.tagName).toUpperCase();var r=!(m in oa)&&13==l;g="INPUT"!=g.tagName.toUpperCase()||!!g.type;l=(0==oa[m]%l||r)&&g}}l&&(n="clickkey")}g=c.srcElement||c.target;l=B(n,c,g,"",null);for(m=g;m&&m!=this;m=m.__owner||m.parentNode){var k=m;b:{var q=void 0;var t=k;r=n;var ka=c;var p=t.__jsaction;
# if(!p){var y;p=null;"getAttribute"in t&&(p=t.getAttribute("jsaction"));if(y=p){p=u[y];if(!p){p={};for(var K=y.split(wa),Ga=K?K.length:0,L=0;L<Ga;L++){var C=K[L];if(C){var M=C.indexOf(":"),la=-1!=M;p[la?va(C.substr(0,M)):"click"]=la?va(C.substr(M+1)):C}}u[y]=p}t.__jsaction=p}else p=ya,t.__jsaction=p}"maybe_click"==r&&p.click?(q=r,r="click"):"clickkey"==r?r="click":"click"!=r||p.click||(r="clickonly");y=null;if(p.click){t=za(t,ka,p);if(!t){q={f:r,action:"",event:null,l:!0};break b}t!=ka&&(y=t,r=t.type)}q=
# {f:q?q:r,action:p[r]||"",event:y,l:!1}}if(q.l||q.action)break}q&&(l=B(q.f,q.event||c,g,q.action||"",k,l.timeStamp));l&&"touchend"==l.eventType&&(l.event._preventMouseEvents=na);if(q&&q.action){if(g="clickkey"==n)g=x(c),g=(g.type||g.tagName).toUpperCase(),(g=32==(c.which||c.keyCode)&&"CHECKBOX"!=g)||(g=x(c),m=g.tagName.toUpperCase(),q=(g.getAttribute("role")||"").toUpperCase(),g="BUTTON"===m||"BUTTON"===q?!0:!(g.tagName.toUpperCase()in ra)||"A"===m||"SELECT"===m||(g.getAttribute("type")||g.tagName).toUpperCase()in
# pa||(g.getAttribute("type")||g.tagName).toUpperCase()in qa?!1:!0);g&&(c.preventDefault?c.preventDefault():c.returnValue=!1);if("mouseenter"==n||"mouseleave"==n)if(g=c.relatedTarget,!("mouseover"==c.type&&"mouseenter"==n||"mouseout"==c.type&&"mouseleave"==n)||g&&(g===k||ba(k,g)))l.action="",l.actionElement=null;else{n={};for(var w in c)"function"!==typeof c[w]&&"srcElement"!==w&&"target"!==w&&(n[w]=c[w]);n.type="mouseover"==c.type?"mouseenter":"mouseleave";n.target=n.srcElement=k;n.bubbles=!1;l.event=
# n;l.targetElement=k}}else l.action="",l.actionElement=null;k=l;a.b&&!k.event.a11ysgd&&(w=B(k.eventType,k.event,k.targetElement,k.action,k.actionElement,k.timeStamp),"clickonly"==w.eventType&&(w.eventType="click"),a.b(w,!0));if(k.actionElement){if(a.b){if(!k.actionElement||"A"!=k.actionElement.tagName||"click"!=k.eventType&&"clickmod"!=k.eventType||(c.preventDefault?c.preventDefault():c.returnValue=!1),(c=a.b(k))&&h){v.call(this,c,!1);return}}else{if((h=e.document)&&!h.createEvent&&h.createEventObject)try{var N=
# h.createEventObject(c)}catch(Ma){N=c}else N=c;k.event=N;a.g.push(k)}"touchend"==k.event.type&&k.event._mouseEventsPrevented&&(A=ia(k.event))}}}function B(a,b,d,c,h,v){return{eventType:a,event:b,targetElement:d,action:c,actionElement:h,timeStamp:v||f()}}var ya={};
# function za(a,b,d){if("click"==b.type||b.targetTouches&&1<b.targetTouches.length)return b;var c=z,h=b.target;if(h&&Aa(h))return b;h=ha(b);if("touchstart"!=b.type||d.touchstart||d.touchend)if("touchend"==b.type&&c&&c.node==a)if(b.defaultPrevented||h&&4<Math.abs(h.clientX-c.x)+Math.abs(h.clientY-c.y))z=null;else{A=a=ia(b);b.stopPropagation();b.preventDefault();document.createEvent?(b=document.createEvent("MouseEvent"),b.initMouseEvent(a.type,!0,!0,window,a.detail||1,a.screenX||0,a.screenY||0,a.clientX||
# 0,a.clientY||0,a.ctrlKey||!1,a.altKey||!1,a.shiftKey||!1,a.metaKey||!1,a.button||0,a.relatedTarget||null)):(b=document.createEventObject(),b.type=a.type,b.clientX=a.clientX,b.clientY=a.clientY,b.button=a.button,b.detail=a.detail,b.ctrlKey=a.ctrlKey,b.altKey=a.altKey,b.shiftKey=a.shiftKey,b.metaKey=a.metaKey);b.m=a.timeStamp;b._fastclick=!0;a:{for(d=a.target;d&&d.getAttribute;){c=d.tagName||"";if("A"==c||"INPUT"==c||"TEXTAREA"==c||"SELECT"==c||"BUTTON"==c||d.getAttribute("tabIndex"))break a;d=d.parentNode}d=
# null}d?d.focus():document.activeElement&&document.activeElement.blur();a.target.dispatchEvent(b);if(!b.defaultPrevented){if(document.activeElement&&document.activeElement!=b.target&&document.activeElement!=d&&Aa(document.activeElement))try{document.activeElement.blur()}catch(v){}try{window.getSelection().removeAllRanges()}catch(v){}}return null}else"touchmove"==b.type&&c&&h&&4<Math.abs(h.clientX-c.x)+Math.abs(h.clientY-c.y)&&(z=null);else return z={node:a,x:h?h.clientX:0,y:h?h.clientY:0},A=null,clearTimeout(ta),
# ta=setTimeout(Ba,400),null;return b}function Aa(a){var b=a.tagName||"";return"TEXTAREA"==b||"INPUT"==b||"SELECT"==b||"OPTION"==b||a.isContentEditable}function Ba(){z=null}function D(a){if(!a._fastclick){var b=A;if(b)if(800<f()-b.timeStamp)A=null;else{var d=4>=Math.abs(a.clientX-b.clientX)+Math.abs(a.clientY-b.clientY);b.target==a.target||d?(a.stopPropagation(),a.preventDefault(),"click"==a.type&&(A=null)):A=null}}}
# function Ca(a,b){return function(d){var c=a,h=b,v=!1;"mouseenter"==c?c="mouseover":"mouseleave"==c&&(c="mouseout");if(d.addEventListener){if("focus"==c||"blur"==c||"error"==c||"load"==c)v=!0;d.addEventListener(c,h,v)}else d.attachEvent&&("focus"==c?c="focusin":"blur"==c&&(c="focusout"),h=ca(d,h),d.attachEvent("on"+c,h));return{f:c,h:h,capture:v}}}
# function E(a,b,d){if(!a.i.hasOwnProperty(b)){var c=xa(a,b);d=Ca(d||b,c);a.i[b]=c;a.j.push(d);for(c=0;c<a.a.length;++c){var h=a.a[c];h.b.push(d.call(null,h.a))}"click"==b&&E(a,"keydown");"click"==b&&(E(a,"touchstart"),E(a,"touchend"),E(a,"touchmove"),document.addEventListener&&(document.addEventListener("click",D,!0),document.addEventListener("mouseup",D,!0),document.addEventListener("mousedown",D,!0)))}}sa.prototype.h=function(a){return this.i[a]};
# function Da(a){var b=F,d=a.a;ua&&(d.style.cursor="pointer");for(d=0;d<b.j.length;++d)a.b.push(b.j[d].call(null,a.a))}function Ea(a){for(var b=Fa,d=0;d<b.length;++d)if(b[d].a!=a.a&&Ha(b[d].a,a.a))return!0;return!1}function Ha(a,b){for(;a!=b&&b.parentNode;)b=b.parentNode;return a==b};var G=window,F=new sa;var Ia=G.document.documentElement,H=new function(a){this.a=a;this.b=[]}(Ia),I;b:{for(var J=0;J<F.a.length;J++)if(Ha(F.a[J].a,Ia)){I=!0;break b}I=!1}
# if(I)F.c.push(H);else{Da(H);F.a.push(H);for(var Fa=F.c.concat(F.a),O=[],P=[],Q=0;Q<F.a.length;++Q){var R=F.a[Q];if(Ea(R)){O.push(R);for(var S=0;S<R.b.length;++S){var T=R.a,U=R.b[S];T.removeEventListener?T.removeEventListener(U.f,U.h,U.capture):T.detachEvent&&T.detachEvent("on"+U.f,U.h)}R.b=[]}else P.push(R)}for(var V=0;V<F.c.length;++V){var W=F.c[V];Ea(W)?O.push(W):(P.push(W),Da(W))}F.a=P;F.c=O}E(F,"click");E(F,"dblclick");E(F,"focus");E(F,"focusin");E(F,"blur");E(F,"error");E(F,"focusout");E(F,"keydown");
# E(F,"keyup");E(F,"keypress");E(F,"load");E(F,"mouseover");E(F,"mouseout");E(F,"mouseenter");E(F,"mouseleave");E(F,"submit");E(F,"touchstart");E(F,"touchend");E(F,"touchmove");E(F,"auxclick");E(F,"change");E(F,"compositionstart");E(F,"compositionupdate");E(F,"compositionend");E(F,"input");E(F,"textinput");E(F,"copy");E(F,"cut");E(F,"paste");E(F,"mousedown");E(F,"mouseup");E(F,"wheel");E(F,"contextmenu");E(F,"dragover");E(F,"dragenter");E(F,"dragleave");E(F,"drop");E(F,"dragstart");E(F,"dragend");
# var Ja,Ka;"onwebkitanimationend"in G&&(Ja="webkitAnimationEnd");E(F,"animationend",Ja);"onwebkittransitionend"in G&&(Ka="webkitTransitionEnd");E(F,"transitionend",Ka);var La=function(a){return{trigger:function(b){var d=a.h(b.type);d||(E(a,b.type),d=a.h(b.type));var c=b.target||b.srcElement;d&&d.call(c.ownerDocument.documentElement,b)},bind:function(b){a.b=b;a.g&&(0<a.g.length&&b(a.g),a.g=null)}}}(F),X=["BOQ_wizbind"],Y=window||e;X[0]in Y||"undefined"==typeof Y.execScript||Y.execScript("var "+X[0]);
# for(var Z;X.length&&(Z=X.shift());)X.length||void 0===La?Y[Z]&&Y[Z]!==Object.prototype[Z]?Y=Y[Z]:Y=Y[Z]={}:Y[Z]=La;}).call(this);
#   </script>
#   <script href="https://www.gstatic.com/_/mss/boq-dots/_/js/k=boq-dots.DotsSplashUi.en_IN.luc2kNNg3G0.es5.O/am=CrEtAAQg/d=1/excm=_b,_tp,collection/ed=1/dg=0/wt=2/ct=zgms/rs=ALs0n2NPUQLYLAGRJ2CNBAhWhovcDNuV9g/m=_b,_tp" id="base-js" nocollect="" nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    "use strict";this.default_DotsSplashUi=this.default_DotsSplashUi||{};(function(_){var window=this;
# try{
# var aaa,baa,caa,daa,eaa,faa,Ra,haa,iaa,ba,hc,jaa,mc,xc,laa,Cc,Dc,maa,Nc,Oc;_.ca=function(a){return function(){return ba[a].apply(this,arguments)}};_.da=function(a,b){return ba[a]=b};_.n=function(){!fa&&ha&&(fa=ha());return fa};_.ia=function(a,b){return(b=b.WIZ_global_data)&&a in b?b[a]:null};aaa=function(a){var b=a.gEa;_.ka(a)&&(b=a.Eb?!a.Eb.fatal:void 0);return b};baa=function(a){var b=a.Zq;_.ka(a)&&(b=a.Eb?a.Eb.Zq:void 0);return b};
# caa=function(a,b){var c=baa(a);if(null==c||0>c)return b;var d=!1;b.then(function(){d=!0},function(){});c=_.na(c,_.oa(null));a.Eb&&(a.Eb.yM=!1);c.then(function(){a.Eb&&(a.Eb.yM=!d)});return _.pa([b,c])};daa=function(a,b){return aaa(a)?_.sa(b,function(){return _.oa(null)}):b};
# eaa=function(a,b){return _.ka(a)&&a.Eb&&a.Eb.h3?b.then(function(c){if(!c&&a.Eb&&a.Eb.yM){c=new ta;var d=new _.va,e;e||(e="type.googleapis.com/");"/"!=e.substr(-1)?_.wa(d,1,e+"/wiz.data.clients.WizDataTimeoutError"):_.wa(d,1,e+"wiz.data.clients.WizDataTimeoutError");_.u(d,2,c.Oc());e=[d];c=new _.xa;c=_.ya(c,1,2,0);return _.za(c,3,e)}return null},function(c){return"undefined"!=typeof _.Aa&&c instanceof _.Aa?c.status:null}):b};
# _.Ha=function(a){if(!_.Da.has("startup"))throw Error("ha`startup");_.Ea.has("startup")?a.apply():_.Fa.startup.push(a)};
# faa=function(a){var b=!0;b=void 0===b?!1:b;a=void 0===a?!1:a;var c="",d="";window&&window._F_cssRowKey&&(c=window._F_cssRowKey,window._F_combinedSignature&&(d=window._F_combinedSignature));if(c&&"function"!==typeof window._F_installCss)throw Error("ma");var e="";var f=_.Ja._F_jsUrl,g=document.getElementById("base-js");if(g){var h=g.tagName.toUpperCase();if("SCRIPT"==h||"LINK"==h)e=g.src?g.src:g.getAttribute("href")}if(f&&e){if(f!=e)throw Error("ka`"+f+"`"+e);e=f}else e=f||e;if(!La(e))throw Error("la");
# a=new _.Ma(_.Pa(e),c,d,b,a);b=_.n();b.Wa=a;b.zP(!0);return a};Ra=function(a){a=a.__soy;a.T3();return a};haa=function(a){for(;a&&!a.SI&&!gaa(a);)a=a.parentElement;return{element:a,FM:a.SI}};
# iaa=function(){_.Ta({Qa:function(a){var b=a.ua?a.ua().el():a.am();var c=b.__soy?Ra(b):null;if(c)return _.oa(c);var d=haa(b),e=d.element;e.pB||(e.pB=new Set);var f=e.pB;c=new Set;for(var g=_.Va(f),h=g.next();!h.done;h=g.next())h=h.value,_.Ya(b,h)&&c.add(h);c.size||(f.add(b),b.__soy_tagged_for_skip=!0);a=d.FM?d.FM.then(function(){f.clear();var l=b.__soy?Ra(b):null;if(l)return l;e.__soy.render();return Ra(b)}):_.mb([a.Hi(_.nb,d.element),_.Vb(a,{Ca:{Dz:_.Zb}})]).then(function(l){var m=l[1].Ca.Dz;return l[0].oW().then(function(p){f.clear();
# e.__incrementalDOMData||(_.dc(e),m.oY(e,p.template,p.args));return Ra(b)})});b.pB=c;return b.SI=a}})};ba=[];hc=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}};_.Va=function(a){var b="undefined"!=typeof Symbol&&Symbol.iterator&&a[Symbol.iterator];return b?b.call(a):{next:hc(a)}};_.ic=function(a){if(!(a instanceof Array)){a=_.Va(a);for(var b,c=[];!(b=a.next()).done;)c.push(b.value);a=c}return a};
# jaa="function"==typeof Object.create?Object.create:function(a){var b=function(){};b.prototype=a;return new b};if("function"==typeof Object.setPrototypeOf)mc=Object.setPrototypeOf;else{var rc;a:{var kaa={a:!0},wc={};try{wc.__proto__=kaa;rc=wc.a;break a}catch(a){}rc=!1}mc=rc?function(a,b){a.__proto__=b;if(a.__proto__!==b)throw new TypeError("a`"+a);return a}:null}xc=mc;
# _.v=function(a,b){a.prototype=jaa(b.prototype);a.prototype.constructor=a;if(xc)xc(a,b);else for(var c in b)if("prototype"!=c)if(Object.defineProperties){var d=Object.getOwnPropertyDescriptor(b,c);d&&Object.defineProperty(a,c,d)}else a[c]=b[c];a.Ec=b.prototype};laa=function(a){a=["object"==typeof globalThis&&globalThis,a,"object"==typeof window&&window,"object"==typeof self&&self,"object"==typeof global&&global];for(var b=0;b<a.length;++b){var c=a[b];if(c&&c.Math==Math)return c}throw Error("b");};
# _.yc=laa(this);Cc="function"==typeof Object.defineProperties?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a};Dc=function(a,b){if(b){var c=_.yc;a=a.split(".");for(var d=0;d<a.length-1;d++){var e=a[d];e in c||(c[e]={});c=c[e]}a=a[a.length-1];d=c[a];b=b(d);b!=d&&null!=b&&Cc(c,a,{configurable:!0,writable:!0,value:b})}};
# Dc("Symbol",function(a){if(a)return a;var b=function(e,f){this.j=e;Cc(this,"description",{configurable:!0,writable:!0,value:f})};b.prototype.toString=function(){return this.j};var c=0,d=function(e){if(this instanceof d)throw new TypeError("c");return new b("jscomp_symbol_"+(e||"")+"_"+c++,e)};return d});
# var Gc=function(){Gc=function(){};var a=Symbol.iterator;a||(a=Symbol.iterator=Symbol("d"));"function"!=typeof Array.prototype[a]&&Cc(Array.prototype,a,{configurable:!0,writable:!0,value:function(){return Hc(hc(this))}})},Hc=function(a){Gc();a={next:a};a[Symbol.iterator]=function(){return this};return a},Ic=function(){this.ma=!1;this.H=null;this.o=void 0;this.j=1;this.va=this.w=0;this.V=null},Jc=function(a){if(a.ma)throw new TypeError("f");a.ma=!0};Ic.prototype.Aa=function(a){this.o=a};
# var Kc=function(a,b){a.V={yK:b,FY:!0};a.j=a.w||a.va};Ic.prototype.return=function(a){this.V={return:a};this.j=this.va};_.w=function(a,b,c){a.j=c;return{value:b}};_.Lc=function(a){a.j=0};_.Mc=function(a){this.j=new Ic;this.o=a};maa=function(a,b){Jc(a.j);var c=a.j.H;if(c)return Nc(a,"return"in c?c["return"]:function(d){return{value:d,done:!0}},b,a.j.return);a.j.return(b);return Oc(a)};
# Nc=function(a,b,c,d){try{var e=b.call(a.j.H,c);if(!(e instanceof Object))throw new TypeError("e`"+e);if(!e.done)return a.j.ma=!1,e;var f=e.value}catch(g){return a.j.H=null,Kc(a.j,g),Oc(a)}a.j.H=null;d.call(a.j,f);return Oc(a)};Oc=function(a){for(;a.j.j;)try{var b=a.o(a.j);if(b)return a.j.ma=!1,{value:b.value,done:!1}}catch(c){a.j.o=void 0,Kc(a.j,c)}a.j.ma=!1;if(a.j.V){b=a.j.V;a.j.V=null;if(b.FY)throw b.yK;return{value:b.return,done:!0}}return{value:void 0,done:!0}};
# _.Pc=function(a){this.next=function(b){Jc(a.j);a.j.H?b=Nc(a,a.j.H.next,b,a.j.Aa):(a.j.Aa(b),b=Oc(a));return b};this.throw=function(b){Jc(a.j);a.j.H?b=Nc(a,a.j.H["throw"],b,a.j.Aa):(Kc(a.j,b),b=Oc(a));return b};this.return=function(b){return maa(a,b)};Gc();this[Symbol.iterator]=function(){return this}};_.Qc=function(a,b){b=new _.Pc(new _.Mc(b));xc&&xc(b,a.prototype);return b};
# Dc("Promise",function(a){function b(){this.j=null}function c(g){return g instanceof e?g:new e(function(h){h(g)})}if(a)return a;b.prototype.o=function(g){if(null==this.j){this.j=[];var h=this;this.w(function(){h.V()})}this.j.push(g)};var d=_.yc.setTimeout;b.prototype.w=function(g){d(g,0)};b.prototype.V=function(){for(;this.j&&this.j.length;){var g=this.j;this.j=[];for(var h=0;h<g.length;++h){var l=g[h];g[h]=null;try{l()}catch(m){this.H(m)}}}this.j=null};b.prototype.H=function(g){this.w(function(){throw g;
# })};var e=function(g){this.Qb=0;this.Gf=void 0;this.j=[];var h=this.w();try{g(h.resolve,h.reject)}catch(l){h.reject(l)}};e.prototype.w=function(){function g(m){return function(p){l||(l=!0,m.call(h,p))}}var h=this,l=!1;return{resolve:g(this.va),reject:g(this.o)}};e.prototype.va=function(g){if(g===this)this.o(new TypeError("g"));else if(g instanceof e)this.Da(g);else{a:switch(typeof g){case "object":var h=null!=g;break a;case "function":h=!0;break a;default:h=!1}h?this.Aa(g):this.H(g)}};e.prototype.Aa=
# function(g){var h=void 0;try{h=g.then}catch(l){this.o(l);return}"function"==typeof h?this.Fa(h,g):this.H(g)};e.prototype.o=function(g){this.V(2,g)};e.prototype.H=function(g){this.V(1,g)};e.prototype.V=function(g,h){if(0!=this.Qb)throw Error("h`"+g+"`"+h+"`"+this.Qb);this.Qb=g;this.Gf=h;this.ma()};e.prototype.ma=function(){if(null!=this.j){for(var g=0;g<this.j.length;++g)f.o(this.j[g]);this.j=null}};var f=new b;e.prototype.Da=function(g){var h=this.w();g.Ax(h.resolve,h.reject)};e.prototype.Fa=function(g,
# h){var l=this.w();try{g.call(h,l.resolve,l.reject)}catch(m){l.reject(m)}};e.prototype.then=function(g,h){function l(r,t){return"function"==typeof r?function(x){try{m(r(x))}catch(z){p(z)}}:t}var m,p,q=new e(function(r,t){m=r;p=t});this.Ax(l(g,m),l(h,p));return q};e.prototype.catch=function(g){return this.then(void 0,g)};e.prototype.Ax=function(g,h){function l(){switch(m.Qb){case 1:g(m.Gf);break;case 2:h(m.Gf);break;default:throw Error("i`"+m.Qb);}}var m=this;null==this.j?f.o(l):this.j.push(l)};e.resolve=
# c;e.reject=function(g){return new e(function(h,l){l(g)})};e.race=function(g){return new e(function(h,l){for(var m=_.Va(g),p=m.next();!p.done;p=m.next())c(p.value).Ax(h,l)})};e.all=function(g){var h=_.Va(g),l=h.next();return l.done?c([]):new e(function(m,p){function q(x){return function(z){r[x]=z;t--;0==t&&m(r)}}var r=[],t=0;do r.push(void 0),t++,c(l.value).Ax(q(r.length-1),p),l=h.next();while(!l.done)})};return e});
# var Rc=function(a,b,c){a instanceof String&&(a=String(a));for(var d=a.length,e=0;e<d;e++){var f=a[e];if(b.call(c,f,e,a))return{GM:e,rQ:f}}return{GM:-1,rQ:void 0}};Dc("Array.prototype.findIndex",function(a){return a?a:function(b,c){return Rc(this,b,c).GM}});Dc("Array.prototype.find",function(a){return a?a:function(b,c){return Rc(this,b,c).rQ}});var Sc=function(a,b,c){if(null==a)throw new TypeError("j`"+c);if(b instanceof RegExp)throw new TypeError("k`"+c);return a+""};
# Dc("String.prototype.endsWith",function(a){return a?a:function(b,c){var d=Sc(this,b,"endsWith");void 0===c&&(c=d.length);c=Math.max(0,Math.min(c|0,d.length));for(var e=b.length;0<e&&0<c;)if(d[--c]!=b[--e])return!1;return 0>=e}});Dc("String.prototype.startsWith",function(a){return a?a:function(b,c){var d=Sc(this,b,"startsWith"),e=d.length,f=b.length;c=Math.max(0,Math.min(c|0,d.length));for(var g=0;g<f&&c<e;)if(d[c++]!=b[g++])return!1;return g>=f}});
# Dc("String.prototype.repeat",function(a){return a?a:function(b){var c=Sc(this,null,"repeat");if(0>b||1342177279<b)throw new RangeError("l");b|=0;for(var d="";b;)if(b&1&&(d+=c),b>>>=1)c+=c;return d}});var Tc=function(a,b){return Object.prototype.hasOwnProperty.call(a,b)};
# Dc("WeakMap",function(a){function b(){}function c(l){var m=typeof l;return"object"===m&&null!==l||"function"===m}function d(l){if(!Tc(l,f)){var m=new b;Cc(l,f,{value:m})}}function e(l){var m=Object[l];m&&(Object[l]=function(p){if(p instanceof b)return p;d(p);return m(p)})}if(function(){if(!a||!Object.seal)return!1;try{var l=Object.seal({}),m=Object.seal({}),p=new a([[l,2],[m,3]]);if(2!=p.get(l)||3!=p.get(m))return!1;p.delete(l);p.set(m,4);return!p.has(l)&&4==p.get(m)}catch(q){return!1}}())return a;
# var f="$jscomp_hidden_"+Math.random();e("freeze");e("preventExtensions");e("seal");var g=0,h=function(l){this.j=(g+=Math.random()+1).toString();if(l){l=_.Va(l);for(var m;!(m=l.next()).done;)m=m.value,this.set(m[0],m[1])}};h.prototype.set=function(l,m){if(!c(l))throw Error("m");d(l);if(!Tc(l,f))throw Error("n`"+l);l[f][this.j]=m;return this};h.prototype.get=function(l){return c(l)&&Tc(l,f)?l[f][this.j]:void 0};h.prototype.has=function(l){return c(l)&&Tc(l,f)&&Tc(l[f],this.j)};h.prototype.delete=function(l){return c(l)&&
# Tc(l,f)&&Tc(l[f],this.j)?delete l[f][this.j]:!1};return h});Dc("Object.is",function(a){return a?a:function(b,c){return b===c?0!==b||1/b===1/c:b!==b&&c!==c}});Dc("Array.prototype.includes",function(a){return a?a:function(b,c){var d=this;d instanceof String&&(d=String(d));var e=d.length;c=c||0;for(0>c&&(c=Math.max(c+e,0));c<e;c++){var f=d[c];if(f===b||Object.is(f,b))return!0}return!1}});
# Dc("String.prototype.includes",function(a){return a?a:function(b,c){return-1!==Sc(this,b,"includes").indexOf(b,c||0)}});Dc("Object.values",function(a){return a?a:function(b){var c=[],d;for(d in b)Tc(b,d)&&c.push(b[d]);return c}});var Uc=function(a,b){Gc();a instanceof String&&(a+="");var c=0,d={next:function(){if(c<a.length){var e=c++;return{value:b(e,a[e]),done:!1}}d.next=function(){return{done:!0,value:void 0}};return d.next()}};d[Symbol.iterator]=function(){return d};return d};
# Dc("Array.prototype.keys",function(a){return a?a:function(){return Uc(this,function(b){return b})}});
# Dc("Map",function(a){if(function(){if(!a||"function"!=typeof a||!a.prototype.entries||"function"!=typeof Object.seal)return!1;try{var h=Object.seal({x:4}),l=new a(_.Va([[h,"s"]]));if("s"!=l.get(h)||1!=l.size||l.get({x:4})||l.set({x:4},"t")!=l||2!=l.size)return!1;var m=l.entries(),p=m.next();if(p.done||p.value[0]!=h||"s"!=p.value[1])return!1;p=m.next();return p.done||4!=p.value[0].x||"t"!=p.value[1]||!m.next().done?!1:!0}catch(q){return!1}}())return a;Gc();var b=new WeakMap,c=function(h){this.o={};
# this.j=f();this.size=0;if(h){h=_.Va(h);for(var l;!(l=h.next()).done;)l=l.value,this.set(l[0],l[1])}};c.prototype.set=function(h,l){h=0===h?0:h;var m=d(this,h);m.list||(m.list=this.o[m.id]=[]);m.mg?m.mg.value=l:(m.mg={next:this.j,ek:this.j.ek,head:this.j,key:h,value:l},m.list.push(m.mg),this.j.ek.next=m.mg,this.j.ek=m.mg,this.size++);return this};c.prototype.delete=function(h){h=d(this,h);return h.mg&&h.list?(h.list.splice(h.index,1),h.list.length||delete this.o[h.id],h.mg.ek.next=h.mg.next,h.mg.next.ek=
# h.mg.ek,h.mg.head=null,this.size--,!0):!1};c.prototype.clear=function(){this.o={};this.j=this.j.ek=f();this.size=0};c.prototype.has=function(h){return!!d(this,h).mg};c.prototype.get=function(h){return(h=d(this,h).mg)&&h.value};c.prototype.entries=function(){return e(this,function(h){return[h.key,h.value]})};c.prototype.keys=function(){return e(this,function(h){return h.key})};c.prototype.values=function(){return e(this,function(h){return h.value})};c.prototype.forEach=function(h,l){for(var m=this.entries(),
# p;!(p=m.next()).done;)p=p.value,h.call(l,p[1],p[0],this)};c.prototype[Symbol.iterator]=c.prototype.entries;var d=function(h,l){var m=l&&typeof l;"object"==m||"function"==m?b.has(l)?m=b.get(l):(m=""+ ++g,b.set(l,m)):m="p_"+l;var p=h.o[m];if(p&&Tc(h.o,m))for(h=0;h<p.length;h++){var q=p[h];if(l!==l&&q.key!==q.key||l===q.key)return{id:m,list:p,index:h,mg:q}}return{id:m,list:p,index:-1,mg:void 0}},e=function(h,l){var m=h.j;return Hc(function(){if(m){for(;m.head!=h.j;)m=m.ek;for(;m.next!=m.head;)return m=
# m.next,{done:!1,value:l(m)};m=null}return{done:!0,value:void 0}})},f=function(){var h={};return h.ek=h.next=h.head=h},g=0;return c});
# Dc("Set",function(a){if(function(){if(!a||"function"!=typeof a||!a.prototype.entries||"function"!=typeof Object.seal)return!1;try{var c=Object.seal({x:4}),d=new a(_.Va([c]));if(!d.has(c)||1!=d.size||d.add(c)!=d||1!=d.size||d.add({x:4})!=d||2!=d.size)return!1;var e=d.entries(),f=e.next();if(f.done||f.value[0]!=c||f.value[1]!=c)return!1;f=e.next();return f.done||f.value[0]==c||4!=f.value[0].x||f.value[1]!=f.value[0]?!1:e.next().done}catch(g){return!1}}())return a;Gc();var b=function(c){this.j=new Map;
# if(c){c=_.Va(c);for(var d;!(d=c.next()).done;)this.add(d.value)}this.size=this.j.size};b.prototype.add=function(c){c=0===c?0:c;this.j.set(c,c);this.size=this.j.size;return this};b.prototype.delete=function(c){c=this.j.delete(c);this.size=this.j.size;return c};b.prototype.clear=function(){this.j.clear();this.size=0};b.prototype.has=function(c){return this.j.has(c)};b.prototype.entries=function(){return this.j.entries()};b.prototype.values=function(){return this.j.values()};b.prototype.keys=b.prototype.values;
# b.prototype[Symbol.iterator]=b.prototype.values;b.prototype.forEach=function(c,d){var e=this;this.j.forEach(function(f){return c.call(d,f,f,e)})};return b});Dc("Array.from",function(a){return a?a:function(b,c,d){c=null!=c?c:function(h){return h};var e=[],f="undefined"!=typeof Symbol&&Symbol.iterator&&b[Symbol.iterator];if("function"==typeof f){b=f.call(b);for(var g=0;!(f=b.next()).done;)e.push(c.call(d,f.value,g++))}else for(f=b.length,g=0;g<f;g++)e.push(c.call(d,b[g],g));return e}});
# Dc("Array.prototype.values",function(a){return a?a:function(){return Uc(this,function(b,c){return c})}});var naa="function"==typeof Object.assign?Object.assign:function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(d)for(var e in d)Tc(d,e)&&(a[e]=d[e])}return a};Dc("Object.assign",function(a){return a||naa});Dc("Number.isNaN",function(a){return a?a:function(b){return"number"===typeof b&&isNaN(b)}});
# ...
# ]
# ]
# ,null,null,null,null,"aa|..."]
# ,[3,null,null,[2,[2,"CAIiEO9ep44JxBDRGhKhFs_t890qGQgEKhAIACoHCAowzrL9CjDC7vQCMJmD1wU"]
# ,"India can avoid 72% of projected Covid cases by closing red light areas: Report","WASHINGTON: India can add 17 days of additional delay to reaching the peak of novel coronavirus cases, and prevent 72 per cent of projected new cases by ...",[1589628342,711000000]
# ,null,"https://timesofindia.indiatimes.com/india/india-can-avoid-72-of-projected-covid-cases-by-closing-red-light-areas-report/articleshow/75772687.cms","https://news.google.com/s/CBIwxcik5UY?oc\u003d3",[["https://lh3.googleusercontent.com/OVwz0y4udifVDaCiRsEiCl3XYEk8dbhgklqsb0HpQVRApE8I8BFwYOyCj95v5NUZOb_3lzvzN0XeRqSCF8E","",945,613,"","CAUqLwgCIhDvXqeOCcQQ0RoSoRbP7fPdKhkIBCoQCAAqBwgKMM6y_Qowwu70AjCZg9cFMJ_xp6AuagppbWFnZS9qcGVn","https://static.toiimg.com/photo/msid-75772698/75772698.jpg?width\u003d640\u0026resizemode\u003d4"]
# ]
# ,null,[6,[6,"CAAqBwgKMM6y_Qowwu70Ag"]
# ,"Times of India",["https://lh3.googleusercontent.com/vMf4ywVB0d1RuBSCK_FxpZwzw3U00V6sHLt1IjLT9p0h6mIwCyslkMYbAtc5n3Hm9h7HXnWQKRcQ4mH0Kw",null,null,null,null,"CAUqEAgAKgcICjDOsv0KMMLu9AIw-sr5vylqCWltYWdlL3BuZw"]
# ,[]
# ,null,null,null,null,null,null,null,null,[]
# ,null
# ,[]
# ,null,null,null,null,null,null,null,null,[]
# ,null,null,null,null,null,null,null,null,["https://lh3.googleusercontent.com/FtADp1uk8fMlxEeDGZ_LAt0Nxq3nffEo6NiNgv9fTN_o2qFXnBKGXqHW3Frwkis8sQ09aCLyrA",null,2000,200,null,"CAUqBwgKML3LhAswoqnfti1qCWltYWdlL3BuZw"]
# ,["https://lh3.googleusercontent.com/jzDRPD_AtjnaRqXqlTTgB5hLhevFxJeqWGER5753jblhQtWn4KjQlQDq0Z27GLTj3iTkyZI3qcY",null,2000,200,null,"CAUqBwgKML3LhAsw48rlti1qCWltYWdlL3BuZw"]
# ]
# ,[[42,[42,"CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWoyMWJUaGo0QU1FWjVJOFhEOXA2aXdLQUFQAQ"]
# ,null,[]
# ,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[]
# ]
# ]
# ,null,"feedback@sputniknews.com (Nair N.B.. Sputnik International)",null,null,null,null,null,null,[]
# ,null,[]
# ,null,null,null,null,null,[]
# ,null,[]
# ,[]
# ,[]
# ,null,"today",null,[null,[["Go to Sputnik International","publications/CAAqBwgKML3LhAsw1biBAw",[null,null,null,null,null,"link"]
# ,0,null,null,null,null,null,null,null,null,null,null,false]
# ]
# ]
# ,true,"https://sputniknews.com/india/202005161079322489-80000-police-personnel-to-be-part-of-indias-clinical-trial-of-ayurvedic-drugs-for-covid-19/",1,"https://sputniknews.com/amp/india/202005161079322489-80000-police-personnel-to-be-part-of-indias-clinical-trial-of-ayurvedic-drugs-for-covid-19/",null,[[null,null,null,null,"channel_story_360:CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWoyMWJUaGo0QU1FWjVJOFhEOXA2aXdLQUFQAQ",0,141,null,null,null,null,null,null,[]
# ]
# ,null,null,["UA-154971557-13",null,0,null,null,null,null,null,["Sputnik International","Sputnik International"]
# ]
# ]
# ,null,1,null,null,[null,[81,null,null,null,null,null,null,null,[]
# ,null,null,"Dr Patwardhan said the lockdown and social distancing are correct measures, but there should be some physical intervention also."]
# ]
# ]
# ,null,null,null,null,"aa|CAIiENgdhzNW95HhZsr1yneegcsqGQgEKhAIACoHCAowvcuECzDVuIEDMKySxwY"]
# ]
# ,null,null,null,null,null,null,null,"",null,["Read more","stories/CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWoyMWJUaGo0QU1FWjVJOFhEOXA2aXdLQUFQAQ"]
# ,null,3,null,null,null,null,false,null,[]
# ,null,null,[42,[42,"CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWoyMWJUaGo0QU1FWjVJOFhEOXA2aXdLQUFQAQ"]
# ,null,null,[]
# ,null,null,null,null,null,null,null,null,[]
# ]
# ,null,null,null,"ui|997d66ee-04c2-4598-98e7-efcde0e795b4",[[[null,null,null,null,"channel_story_360:CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWoyMWJUaGo0QU1FWjVJOFhEOXA2aXdLQUFQAQ",null,141,null,null,null,null,null,null,[[null,null,null,null,null,["CAAqBwgKMMqAmAsw9KmvAw"]
# ]
# ,1,4]
# ]
# ]
# ,47]
# ]
# ,null,null,null,null,null,"aa|ui|f87d9660-c716-4f09-be85-86cedf25da3d"]
# ]
# ,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"topics/CAAqBwgKMMqAmAsw9KmvAw/sections/CAQqEAgAKgcICjDKgJgLMPSprwMw9snOBg",[]
# ,[[null,null,null,null,null,null,null,null,null,null,null,null,null,[[null,null,null,null,null,["CAAqBwgKMMqAmAsw9KmvAw"]
# ]
# ]
# ]
# ,null,null,[null,null,null,null,null,null,null,[null,null,"COVID-19"]
# ]
# ]
# ,null,null,2,null,null,null,[[[null,null,null,null,null,null,null,null,null,null,null,null,null,[[null,null,null,null,null,["CAAqBwgKMMqAmAsw9KmvAw"]
# ]
# ]
# ]
# ,[null,null,"CAQqEAgAKgcICjDKgJgLMPSprwMw9snOBg",null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,null,"COVID-19"]
# ]
# ]
# ,2]
# ]
# ,null,null,null,null,null,"aa|CAQqEAgAKgcICjDKgJgLMPSprwMw9snOBg"]
# ,null,null,"CAESCwixnoD2BRCA9455"]
# }});
#   </script>
#   <script id="wiz_jd" nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    if (window['_rwjd']) {const wjd = {}; window['_rwjd'](wjd);}
#   </script>
#   <script aria-hidden="true" nonce="lwCtUOf3XK+jC+5QFeIBbA">
#    window.wiz_progress&&window.wiz_progress(); window.stopScanForCss&&window.stopScanForCss(); ccTick('bl');
#   </script>
#  </body>
# </html>

# %%
news_headline=soup.find_all('h3',class_="ipQwMb ekueJc gEATFF RD0gLb") # News Headline
images = soup.findAll('img',class_="tvs3Id QwxBBf") #Image links related to News-headline
link = soup.findAll('a',class_="VDXfz") # News-Headline deatail link

# %%
news_headline_list=[n.text for n in news_headline]
image_link=[j['src'] for j in images]
headline_link=["https://news.google.com/"+str(j['href']) for j in link]

# %%
now.strftime("%H:%M:%S::%d-%b-%Y")
# Out:
# '22:17:41::16-May-2020'

# %%
dic={}
serial=1
for j in range(20):
    dic[now.strftime("%d %b")+" "+str(serial)]={"Headline":news_headline_list[j],"image_link":image_link[j],"headline_link":headline_link[j]}
    serial+=1
print(dic)
with open('google-news.json', 'r+') as file:
    dic = json.load(file)
    dic.update(dic)
    file.seek(0)
    json.dump(dic, file)
# Out:
# {'16 May 1': {'Headline': 'Coronavirus update: COVID-19 cases in India surge past 85,000, death toll at 2,752. State-wise tally', 'image_link': 'https://lh3.googleusercontent.com/FHl0Vcxxk36yF-GrJj9yL4R3_UO0FMn3tsy4eDybavFJYAHe8cZW5OWY_zR-qsPC2ZpW-utX8Dq--Kdq-sE=-p-h100-w100', 'headline_link': 'https://news.google.com/./articles/CAIiEOodbY0nAv1fK7Mc83-cWaMqFwgEKg4IACoGCAowxLQ_MNevCDDnvNMF?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 2': {'Headline': 'Lockdown 4.0 guidelines: How rules will be different from existing ones from May 18', 'image_link': 'https://lh3.googleusercontent.com/KiqJ8LWo1rv_zFiu_GEgrruMK2IEU2HilJP1mO1rNNrx6v6jL9tegu39SbftFtSQM3WE1z44_19uyXrR7Q=-p-h100-w100', 'headline_link': 'https://news.google.com/./articles/CAIiEMmJdpRbMaTbdEQc7iQI3D0qGAgEKg8IACoHCAow3rvTBDD89X4wyN7OBg?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 3': {'Headline': 'COVID-19 vaccine current status: Here are the 9 top contenders for coronavirus vaccines', 'image_link': 'https://lh3.googleusercontent.com/proxy/S0E_nfXtQlBPlhHJOXQUuaTGbd1Khij3DWOweJ1vUZ81oCxYnpCs95ChLBKXurZeLIBptrByjS_zRfgo5T7s=-p-h100-w100', 'headline_link': 'https://news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 4': {'Headline': 'Coronavirus India LIVE Updates: Centre launches online dashboard to monitor info on migrants’ movement', 'image_link': 'https://lh5.googleusercontent.com/proxy/mVhoXIz-ZzOgLS7tQHImc-Bm9mnYFQq94agUTfFp8952jjEhEXPaUfJPX_QU5xd7ctbc10IHcp68R7P19U-3x6pEuXtrRTDCyWSMZ7WRtBi_pKA=-p-h100-w100', 'headline_link': 'https://news.google.com/....?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 5': {'Headline': "No Monkeying! 15 Railway Ministry Officials Under Quarantine And Lutyens' Monkeys Are to be Blamed", 'image_link': 'https://lh3.googleusercontent.com/PYDtI_6pgdsC5g6ea8vemHjyPIHdD6j4iw2JSRfEl6Z8g2bHCTpmbuoYO5m7Q5ZsjDPYVnB7lMupKtQk77I=-p-h100-w100', 'headline_link': 'https://news.google.com/./articles/CAIiEDLRQWmzMY9FwbKfvT_bzk4qGQgEKhAIACoHCAow5dz4CjCO8d4CMJW5iwY?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 6': {'Headline': 'COVID-19 death toll in Delhi rises to 129; 438 fresh cases take tally to 9,333', 'image_link': 'https://lh3.googleusercontent.com/ara_BDPnl0_lzMtIBvBfp5PRZDWjLFQaI2LQpbjyjmHZ8CF_ASGoC8oW61PqN13GcX9YP__r6dj9CZ_jb8c=-p-h100-w100', 'headline_link': 'https://news.google.com/./articles/CAIiEEvfJaCgekW6X8Nk6tekL44qGQgEKhAIACoHCAowyo-HCzD-tIUDMLuIyQY?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 7': {'Headline': "Delhi lockdown news: Today's updates from your city", 'image_link': 'https://lh3.googleusercontent.com/sAszeTX52ZnhqwM5fxxe7etw79rDcaURzCQHeW8Qb9GMrGRheubrLp1P28d7Y4kpY3q1KUGSKtP_7VZHQQM=-p-h100-w100', 'headline_link': 'https://news.google.com/./articles/CAIiEMI16D1advYojLABU8aQyIQqGQgEKhAIACoHCAowzrL9CjDC7vQCMKCT1wU?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 8': {'Headline': 'COVID-19: 15 Inmates, Warden Test Positive For Coronavirus In Delhi Jail', 'image_link': 'https://lh3.googleusercontent.com/JVBg5Z80Bi4IX7X3lBNnmCz-VmHKRfqQvNxqvfpXloqwik2Ebh2dtIf2O4HvpL0QkT8H0AJzsisDAdpDLB8=-p-h100-w100', 'headline_link': 'https://news.google.com/./articles/CAIiEFRRo_Szf35j894z8BuwCIUqGQgEKhAIACoHCAowj8n_CjDIrfkCMPGi6AU?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 9': {'Headline': 'Delhi wants to restart life from Monday — with social distance', 'image_link': 'https://lh3.googleusercontent.com/oFziVhG5bp4qdG-EQ71GrKkdVUdB6I4a33tmb1x0BmBadLvtq6uthIzRf6KbHppMqXM7fDVzaP3SitmIKg=-p-h100-w100', 'headline_link': 'https://news.google.com/./articles/CAIiEFFZzpPPOfeHi7_P5TtqDPAqFwgEKg4IACoGCAoww7k_MMevCDC0rdgG?hl=en-IN&gl=IN&ceid=IN%3Aen'}, '16 May 10': {'Headline': "Koyambedu: India's coronavirus cluster at a vegetable market", 'image_link': 'https://lh6.googleusercontent.com/proxy/dzgfvssWZF5h1j8DmJbWdDqOcJE-IULf-FYbH_gJuiwwwZ9szNSsRmL2LUxubI1NEpKLNU7U7VwnAShh-R3PApvNmmjuy-ITwHStEJKLFxvBNDuZIgYVkLFccxBKNG2zRZJWe2w=-p-h100-w100', 'headline_link': 'https://news.google.com/./articles/CBMiMmh0dHBzOi8vd3d3LmJiYy5jb20vbmV3cy93b3JsZC1hc2lhLWluZGlhLTUyNjc0NjM50gE2aHR0cHM6Ly93d3cuYmJjLmNv ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-66-7fa221a42862> in <module>
#       6 print(dic)
#       7 with open('google-news.json', 'r+') as file:
# ----> 8     dic = json.load(file)
#       9     dic.update(dic)
#      10     file.seek(0)
#
# /usr/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /usr/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
